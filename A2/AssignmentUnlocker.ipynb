# %% [markdown]
# # Unlock your assignment
#
# This notebook will unlock your assignment which has been downloaded but is not yet accessible to you.
#
# You should fill in the **password** which will be revealed to you when you get the assignment. You may **not** reveal the password to anyone else.
#
# Beyond filling in the password, **DO NOT EDIT THIS FILE**

# %%
password = 'almost-march-madness'

# %%
from unlocker import unlock

# You should see a "Unlocking complete" line when the unlocking is complete
print('Beginning the unlock process\n')
rc = unlock('A2.locked', password)
print('\nUnlocking complete')
# Out:
# Beginning the unlock process
#
# Unpacking A2.ipynb
# Unpacking comp421.py
# Unpacking A2.pickle
# Unpacking logger.py
# Unpacking basketball.sqlite
#
# Unlocking complete
